# %% [markdown]
# Montamos el disco de Google Drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Leemos el dataset de entrenamiento limpio

# %%
ROOT = '/content/drive/Othercomputers/Mi MacBook Pro/Google Drive/tp2/'
dataSetPath = './data/smoking_prediction_cleaned.csv'
pd.set_option('display.max_columns', None)
df = pd.read_csv(ROOT + dataSetPath)
df.head()
# Out:
#   gender  age  height(cm)  weight(kg)  waist(cm)  systolic  relaxation  \
# 0      F   40         155          60       3.38      4.75        3.04
# 1      F   40         160          60       3.38      4.96        2.92
# 2      M   55         170          60       3.33      5.75        3.58
# 3      M   40         165          70       3.67      4.17        2.50
# 4      F   40         155          60       3.58      5.00        3.08
#
#    fasting blood sugar  Cholesterol  triglyceride   HDL   LDL  hemoglobin  \
# 0                 3.92         8.96          3.42  3.04  5.25        0.51
# 1                 5.42         8.00          4.79  1.75  5.29        0.50
# 2                 3.71        10.08          7.58  2.29  6.29        0.63
# 3                 4.00        13.42         10.58  1.88  9.42        0.59
# 4                 3.33         7.67          3.08  2.58  4.46        0.50
#
#    Urine protein   AST   ALT   Gtp  dental caries tartar  smoking
# ...

# %% [markdown]
# # **Preparación de los datos**

# %% [markdown]
# Convertimos los valores de la variable *Gender*

# %%
df['gender'] = df['gender'].astype('category')
df['gender'] = df['gender'].cat.codes
df
# Out:
#        gender  age  height(cm)  weight(kg)  waist(cm)  systolic  relaxation  \
# 0           0   40         155          60       3.38      4.75        3.04
# 1           0   40         160          60       3.38      4.96        2.92
# 2           1   55         170          60       3.33      5.75        3.58
# 3           1   40         165          70       3.67      4.17        2.50
# 4           0   40         155          60       3.58      5.00        3.08
# ...       ...  ...         ...         ...        ...       ...         ...
# 49995       1   50         160          55       2.96      5.08        3.00
# 49996       1   30         170          70       3.33      4.67        3.21
# 49997       1   20         165          65       3.54      5.21        3.13
# 49998       0   60         160          45       2.96      4.92        3.25
# 49999       1   45         170          80       4.00      5.63        3.54
#
# ...

# %% [markdown]
# Convertimos los valores de la variable Tartar

# %%
df['tartar'] = df['tartar'].astype('category')
df['tartar'] = df['tartar'].cat.codes
df
# Out:
#        gender  age  height(cm)  weight(kg)  waist(cm)  systolic  relaxation  \
# 0           0   40         155          60       3.38      4.75        3.04
# 1           0   40         160          60       3.38      4.96        2.92
# 2           1   55         170          60       3.33      5.75        3.58
# 3           1   40         165          70       3.67      4.17        2.50
# 4           0   40         155          60       3.58      5.00        3.08
# ...       ...  ...         ...         ...        ...       ...         ...
# 49995       1   50         160          55       2.96      5.08        3.00
# 49996       1   30         170          70       3.33      4.67        3.21
# 49997       1   20         165          65       3.54      5.21        3.13
# 49998       0   60         160          45       2.96      4.92        3.25
# 49999       1   45         170          80       4.00      5.63        3.54
#
# ...

# %% [markdown]
# Exportamos nuestros datos preparados para entrenar el modelo

# %%
df.to_csv(ROOT + './data/smoking_prediction_prepared.csv', index=False)
